# %% [markdown]
# # 🛡️ File Analysis System v3.0
# **Complete Malware Detection Tool**
#
# Created by: Abdul Rehman (22BSCYS053)

# %%
# PASTE YOUR COMPLETE CODE HERE FROM ARTIFACT

# %% [markdown]
# ## 🚀 Start Scanning
# Run the cell below to upload and scan files:

# %%
analyzer.upload_and_scan()
